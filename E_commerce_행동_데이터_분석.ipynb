# %% [markdown]
# # E-commerce 행동 데이터 분석

# %% [markdown]
# ## 1. 분석 목적 정의
# E-commerce 데이터를 분석하여 마케팅, 영업 의사 결정에 활용한다.</br>
# 소비자들을 RFM 기반으로 분석하여 용이한 의사 결정을 보조한다.

# %% [markdown]
# ### 분석 프로세스
# 1. 분석 목표 정의
# 2. 데이터 전처리
# 3. EDA
# 4. ML 분석
#
# ### 활용 분석 모델
# 1. Clustering Algorithm
# 2. RFM scoring Model, RFM model with K-means

# %% [markdown]
# ---
# ## RFM 분석이란?
# ### CRM에서 많이 활용하는 고객 가치 분석 방법론
# - Recency: 최근 구매, 최근 행동
# - Frequency: 방문 빈도, 행동 빈도
# - Monetary: 소비 행동, 얼마나 쓰는가?
#
# #### 자주 구매하며, 최근에도 구매하며, 많이 소비하는 고객을 VIP 고객을 분류하고, 마케팅 전략을 수립하는데 도움이 될 수 있다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# library for feature engineering and EDA
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image
from datetime import datetime
import random

# library for statistic
from scipy import stats
from scipy.stats import skew
from scipy.stats import kurtosis

# library for machine learning
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# %matplotlib inline

# %% [markdown]
# ## 2. Data Processing 1

# %% [markdown]
# ### 2.1. Data Load

# %%
# !pwd
path = "/content/drive/MyDrive/Data Analysis Projects/E-commerce 행동 데이터 분석"
random_state = 1234
# Out:
# /content

# %%
df = pd.read_csv(path + "/Data/data.csv", encoding = 'unicode_escape')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ### 2.2. 중복 Data 확인

# %%
print("중복된 항목 수 :", len(df[df.duplicated()]))
# Out:
# 중복된 항목 수 : 5268

# %%
df = df.drop_duplicates().reset_index(drop = True)

# %% [markdown]
# ## 3. Data EDA

# %% [markdown]
# ### 3.1. Data Type and Summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536641 entries, 0 to 536640
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    536641 non-null  object
#  1   StockCode    536641 non-null  object
#  2   Description  535187 non-null  object
#  3   Quantity     536641 non-null  int64
#  4   InvoiceDate  536641 non-null  object
#  5   UnitPrice    536641 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      536641 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.8+ MB

# %%
# categorical and numerical columns
for column_name in list(df.columns):

    print(column_name,df[column_name].dtype, df[column_name].unique())
# Out:
# InvoiceNo object ['536365' '536366' '536367' ... '581585' '581586' '581587']
# StockCode object ['85123A' '71053' '84406B' ... '90214U' '47591b' '23843']
# Description object ['WHITE HANGING HEART T-LIGHT HOLDER' 'WHITE METAL LANTERN'
#  'CREAM CUPID HEARTS COAT HANGER' ... 'lost'
#  'CREAM HANGING HEART T-LIGHT HOLDER' 'PAPER CRAFT , LITTLE BIRDIE']
# Quantity int64 [     6      8      2     32      3      4     24     12     48     18
#      20     36     80     64     10    120     96     23      5      1
#      -1     50     40    100    192    432    144    288    -12    -24
#      16      9    128     25     30     28      7     56     72    200
#     600    480     -6     14     -2     11     33     13     -4     -5
#      -7     -3     70    252     60    216    384    -10     27     15
#      22     19     17     21     34     47    108     52  -9360    -38
#      75    270     42    240     90    320   1824    204     69    -36
#    -192   -144    160   2880   1400     39    -48    -50     26   1440
#      31     82     78     97     98     35     57    -20    110    -22
#     -30    -70   -130    -80   -120    -40    -25    -14    -15    -69
#    -140   -320     -8    720    156    324     38     37     49     95
#      -9    -11     29     41    -72    -35    -21    -43    -19    -18
#     -44    402    378    150    300     54    104     67    258     66
#      44     55     46     99     61    408    972    208   1008   1000
#     -77   1488    250   1394    400   -223   -150    -13    -33   -723
#    -177     79     84    -32   -100    -28    272   -145    -47    -96
#     113     45    106     68    267    115     65   1728    -60    -16
#      53   -240     76    460     71     43    213     58    576   2400
#     500    180   -300   -500    -23    752    960   1296    210    172
#     215    129    138    116    135    197   -106    -54    -17   -939
#     147    168    256   -201    -53    -29  -2600   -990   -290    -45
#     860   1010   1356   1284    186    114    360   1930   2000   3114
#    1300    670    111    211     59   -310    -61    -41    176    648
#      62  74215 -74215    -64    -84     89  -1400     73    -57    112
#     456    -59    -31   5568   2560    136    900   -600    -42    -94
#    -207    -52    130   -206   2592    420    800    101   1200    864
#    -217     94  -1430   1287   -162   -230   -173   -390   -234    504
#     123    118    -76   -200   1056   1500    280    407    141    124
#     -99     51    -92   -741   3906   -400   -114    102   1152    -88
#     198    117     86   -720    125    -86   -391    -87   -278    140
#     228   -154  -3000     81   -675   -210   -345   -975  -1200  -1121
#     -27   -541  -1277   -197   3000  -1100    -63  -5368    219   -259
#     232    -82   -178    170   -110    768     88    700   -102   2160
#    -323   -450   -232    -83   -153   -524  -2472    -49   -105    342
#     304    167    -34    640    175    220     74     93    164    163
#      63    637    122    158    165    350    -46    -75   -690    -39
#     -66     83    312   -180    392   -624   -194    -26    -62    -37
#     -91   -139   -158  -1479    -55   -576   -750    330    151    -93
#    -432    -58  -1092   -670  -1300  -1930  -2000  -3114    462    -65
#     -68    492   -620    273    -90   -170  -1512    -51     85    -56
#    -160   -360    105   -960  -2376   1350    428  -1350    336   -786
#    -590   -168   -101    -71    132   -413   -664    227   2700    222
#     246    906    756    888    552    -97    224    738    608   -212
#    4300    146    143    276   -125   -116   -108   4000   -304   -272
#   -1206    -95   1600    323   -161   -472   -618   -204   1515  -1515
#   -9058  -9600    660   -420   -126   -220   -271  -1440    264    188
#     588    612    152   -324   -480   -164    -78   -118    430  -1681
#      87    155    701    828    540    696    560   -250   -408   -179
#     121   -124    512   -251  -3100   3100   -169    126    291   3186
#   -2834   -109    109   -121   -530   -227    261   -346    352    142
#     107   -188  -1060   -342   -288    348   1900    157   -343   -455
#     425    968    684    824   -828   -701    196    248    410    236
#     230   -156   -553    145    448    245   -252   -334   -318   -113
#    -115    171   -242    840   -967   -203  -3167   -443  -1897    225
#    -434    750   -682   -484    682    344   -635   -117  -3667    450
#     310    494   -384     92   1788   -138    624    744    416    496
#     396    306   1878   1944    666    708   1428    852   1412    528
#    -756   -752   -152    -85   -312    -79   -147    -67   -131    183
#    -209   -186   -231   -129   -458   -275  -2880   1540    672   -800
#    -430   -380    -74   -840  -1296   -365   -104   -270    -73   -306
#      91    255    468   -468   -111   -184   -103   -335   4800   -112
#   -1000    912   1992    184    148   -657  -1671  -1158  -2618  -2003
#    -674  -4830   -905  -1128    832    992    630   1020   2100    162
#   -1560  -1284    -81    314    370    131    133    484    149    153
#     257    139    137    628    179   1820    478    335    253    242
#     375   -276   -256    281    193    181    404    244    207    199
#    1130    326    654    688    268    249   -864    234  -1510   -550
#    -244   -132   -327   -313    279   -398   -280    374   -504   -696
#    -149   -224   -428    212   -267   -175  12540    760    -98    774
#    -151   2040  -1131   -135   1120     77   -900    177    490    388
#     620   1404   -155   -355   -337  -1050   -338    205   -235    698
#   80995 -80995]
# InvoiceDate object ['12/1/2010 8:26' '12/1/2010 8:28' '12/1/2010 8:34' ... '12/9/2011 12:31'
#  '12/9/2011 12:49' '12/9/2011 12:50']
# UnitPrice float64 [   2.55    3.39    2.75 ...  933.17 1714.17  224.69]
# CustomerID float64 [17850. 13047. 12583. ... 13298. 14569. 12713.]
# Country object ['United Kingdom' 'France' 'Australia' 'Netherlands' 'Germany' 'Norway'
#  'EIRE' 'Switzerland' 'Spain' 'Poland' 'Portugal' 'Italy' 'Belgium'
#  'Lithuania' 'Japan' 'Iceland' 'Channel Islands' 'Denmark' 'Cyprus'
#  'Sweden' 'Austria' 'Israel' 'Finland' 'Bahrain' 'Greece' 'Hong Kong'
#  'Singapore' 'Lebanon' 'United Arab Emirates' 'Saudi Arabia'
#  'Czech Republic' 'Canada' 'Unspecified' 'Brazil' 'USA'
#  'European Community' 'Malta' 'RSA']

# %%
# Customer ID는 카테고리 데이터로 변경
list_cast_to_object = ["CustomerID"]
for column_name in list_cast_to_object:
    df[column_name] = df[column_name].astype(object)

# %%
# 카테고리, 수량 데이터 비교
list_categorical_columns = list(df.select_dtypes(include = ['object']).columns)
list_numerical_columns = list(df.select_dtypes(include = ['float64', 'int64']).columns)
print(len(df))
print(len(df.columns))
print(len(list_categorical_columns))
print(len(list_numerical_columns))
# Out:
# 536641
# 8
# 6
# 2

# %%
list_categorical_columns
# Out:
# ['InvoiceNo',
#  'StockCode',
#  'Description',
#  'InvoiceDate',
#  'CustomerID',
#  'Country']

# %%
list_numerical_columns
# Out:
# ['Quantity', 'UnitPrice']

# %%
# 결측값 확인
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %% [markdown]
# ---
# 데이터 요약
#
# - 변수 8개
# -- 차원 6개, 측정값 2개
# - 행 536,641개
# - 결측값 포함된 필드 2개
# - 중복값 5,268개(제거함)

# %% [markdown]
# ### 3.2. 독립변수 데이터 EDA

# %% [markdown]
# #### 3.2.1. 차원 데이터

# %%
# 불필요한 컬럼 확인
df[list_categorical_columns].nunique().sort_values()
# 이 값만으로는 확인이 어려움
# Out:
# Country           38
# StockCode       4070
# Description     4223
# CustomerID      4372
# InvoiceDate    23260
# InvoiceNo      25900
# dtype: int64

# %%
# 고객 분석에서 Description은 활용 안 할 예정
df = df.drop(["Description"], axis = 1)
list_categorical_columns.remove("Description")

# %%
list_categorical_columns
# Out:
# ['InvoiceNo', 'StockCode', 'InvoiceDate', 'CustomerID', 'Country']

# %%
# 필드별 분포 확인
# 1. 인보이스 번호별로 몇 개의 상품을 구매하는가?
df_invoiceno_count = df.groupby("InvoiceNo").count()["StockCode"]
sns.histplot(df_invoiceno_count)
# Out:
# <Axes: xlabel='StockCode', ylabel='Count'>

# %%
sns.boxplot(df_invoiceno_count)
# Out:
# <Axes: ylabel='StockCode'>

# %%
df_invoiceno_count.describe()
# max 값 확인 필요
# Out:
# count    25900.000000
# mean        20.719730
# std         42.793088
# min          1.000000
# 25%          2.000000
# 50%         10.000000
# 75%         23.000000
# max       1114.000000
# Name: StockCode, dtype: float64

# %%
no_invoice_max = df_invoiceno_count[df_invoiceno_count == max(df_invoiceno_count)]
print(no_invoice_max.index[0])
df[df.InvoiceNo == no_invoice_max.index[0]]

# 해당 count(1114, max)를 갖는 invoice의 Customer ID는 NaN임. 처리할 필요 있음
# Out:
# 573585
#        InvoiceNo     StockCode  Quantity       InvoiceDate  UnitPrice  \
# 426616    573585         11001         2  10/31/2011 14:41       3.29
# 426617    573585         15036        15  10/31/2011 14:41       1.63
# 426618    573585         15039        15  10/31/2011 14:41       1.63
# 426619    573585       15056BL         1  10/31/2011 14:41      12.46
# 426620    573585        15056N         1  10/31/2011 14:41      12.46
# ...          ...           ...       ...               ...        ...
# 427725    573585        90209C         3  10/31/2011 14:41       2.07
# 427726    573585        90214S         1  10/31/2011 14:41       0.83
# 427727    573585           DOT         1  10/31/2011 14:41    2019.05
# 427728    573585  gift_0001_20         1  10/31/2011 14:41      16.67
# 427729    573585         23539         2  10/31/2011 14:41       5.79
#
#        CustomerID         Country
# 426616        NaN  United Kingdom
# 426617        NaN  United Kingdom
# 426618        NaN  United Kingdom
# 426619        NaN  United Kingdom
# 426620        NaN  United Kingdom
# ...           ...             ...
# 427725        NaN  United Kingdom
# 427726        NaN  United Kingdom
# 427727        NaN  United Kingdom
# 427728        NaN  United Kingdom
# 427729        NaN  United Kingdom
#
# [1114 rows x 7 columns]

# %%
df = df.dropna().reset_index(drop = True)

# %%
# 이상치 제거 후 다시 확인
df_invoiceno_count = df.groupby("InvoiceNo").count()["StockCode"]
sns.histplot(df_invoiceno_count)
# Out:
# <Axes: xlabel='StockCode', ylabel='Count'>

# %%
sns.boxplot(df_invoiceno_count)
# Out:
# <Axes: ylabel='StockCode'>

# %%
df_invoiceno_count.describe()
# Out:
# count    22190.000000
# mean        18.098423
# std         23.363888
# min          1.000000
# 25%          3.000000
# 50%         12.000000
# 75%         24.000000
# max        542.000000
# Name: StockCode, dtype: float64

# %%
# max 값 다시 확인
no_invoice_max = df_invoiceno_count[df_invoiceno_count == max(df_invoiceno_count)]
print(no_invoice_max.index[0])
df[df.InvoiceNo == no_invoice_max.index[0]]
# Out:
# 576339
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice CustomerID  \
# 347900    576339     10135        14  11/14/2011 15:27       2.46    14096.0
# 347901    576339    15044A         1  11/14/2011 15:27       5.79    14096.0
# 347902    576339     16238         2  11/14/2011 15:27       0.42    14096.0
# 347903    576339    16258A         1  11/14/2011 15:27       0.83    14096.0
# 347904    576339     17003         2  11/14/2011 15:27       0.63    14096.0
# ...          ...       ...       ...               ...        ...        ...
# 348437    576339     90083         1  11/14/2011 15:27       1.63    14096.0
# 348438    576339     90086         1  11/14/2011 15:27       1.63    14096.0
# 348439    576339     90119        11  11/14/2011 15:27       2.46    14096.0
# 348440    576339     90166         1  11/14/2011 15:27       4.15    14096.0
# 348441    576339       DOT         1  11/14/2011 15:27    1500.36    14096.0
#
#                Country
# 347900  United Kingdom
# 347901  United Kingdom
# 347902  United Kingdom
# 347903  United Kingdom
# 347904  United Kingdom
# ...                ...
# 348437  United Kingdom
# 348438  United Kingdom
# 348439  United Kingdom
# 348440  United Kingdom
# 348441  United Kingdom
#
# [542 rows x 7 columns]

# %%
# 2. 상품별 구매 수?
df.StockCode.nunique()
# Out:
# 3684

# %%
no_stockcode_buy = df.groupby("StockCode").count()["InvoiceNo"]

# %%
no_stockcode_buy.sort_values(ascending = False)
# Out:
# StockCode
# 85123A    2065
# 22423     1894
# 85099B    1659
# 47566     1409
# 84879     1405
#           ...
# 90176B       1
# 90176C       1
# 90069        1
# 90035C       1
# 37461        1
# Name: InvoiceNo, Length: 3684, dtype: int64

# %%
no_stockcode_buy.describe()
# Out:
# count    3684.000000
# mean      109.013029
# std       165.656870
# min         1.000000
# 25%        12.000000
# 50%        48.000000
# 75%       137.000000
# max      2065.000000
# Name: InvoiceNo, dtype: float64

# %%
# 3. 요일별 상품 구매 수 차이?
df["InvoiceDate"] = pd.to_datetime(df.InvoiceDate)

# %%
df_tmp = df

# %%
df_tmp["weekday"] = df.InvoiceDate.dt.weekday
df_tmp["month"] = df.InvoiceDate.dt.month
df_tmp["hour"] = df.InvoiceDate.dt.hour

# %%
df_tmp.head()
# Out:
#   InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice CustomerID  \
# 0    536365    85123A         6 2010-12-01 08:26:00       2.55    17850.0
# 1    536365     71053         6 2010-12-01 08:26:00       3.39    17850.0
# 2    536365    84406B         8 2010-12-01 08:26:00       2.75    17850.0
# 3    536365    84029G         6 2010-12-01 08:26:00       3.39    17850.0
# 4    536365    84029E         6 2010-12-01 08:26:00       3.39    17850.0
#
#           Country  weekday  month  hour
# 0  United Kingdom        2     12     8
# 1  United Kingdom        2     12     8
# 2  United Kingdom        2     12     8
# 3  United Kingdom        2     12     8
# 4  United Kingdom        2     12     8

# %%
df_tmp.groupby("weekday").count()["Quantity"].plot.bar()
# 금요일 데이터 없는 것 확인 -> 누락 가능성 있음
# Out:
# <Axes: xlabel='weekday'>

# %%
df_tmp.groupby("month").count()["Quantity"].plot.bar()
# Out:
# <Axes: xlabel='month'>

# %%
df_tmp.groupby("hour").count()["Quantity"].plot.bar()
# Out:
# <Axes: xlabel='hour'>

# %%
# 4. 국가별 상품 구매 차이?
df.Country.nunique()
# Out:
# 37

# %%
df.groupby("Country").count()["Quantity"].plot.bar()
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ---
# 인사이트
# 1. 한 구매에 다양한 상품을 구매한다.
# 2. 일부 잘 팔리는 제품이 있다.
# 3. 평일에 더 많은 상품을 구매한다. 목요일 판매가 가장 높다. 다만, 금요일 데이터가 없다.
# 4. 정오에 가장 많은 상품을 구매한다.
# 5. 겨울, 특히, 11월에 많이 구매한다.
# 6. 영국 구매 데이터가 가장 많다.

# %% [markdown]
# #### 3.2.2. 측정값 데이터

# %%
df[list_numerical_columns].nunique().sort_values()
# Out:
# Quantity     436
# UnitPrice    620
# dtype: int64

# %%
df[list_numerical_columns].describe()
# Out:
#             Quantity      UnitPrice
# count  401604.000000  401604.000000
# mean       12.183273       3.474064
# std       250.283037      69.764035
# min    -80995.000000       0.000000
# 25%         2.000000       1.250000
# 50%         5.000000       1.950000
# 75%        12.000000       3.750000
# max     80995.000000   38970.000000

# %%
# 필드별 분포 확인
df[df.Quantity < 0]
# 환불 데이터?
# Out:
#        InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  \
# 141      C536379         D        -1 2010-12-01 09:41:00      27.50
# 154      C536383    35004C        -1 2010-12-01 09:49:00       4.65
# 235      C536391     22556       -12 2010-12-01 10:24:00       1.65
# 236      C536391     21984       -24 2010-12-01 10:24:00       0.29
# 237      C536391     21983       -24 2010-12-01 10:24:00       0.29
# ...          ...       ...       ...                 ...        ...
# 401159   C581490     23144       -11 2011-12-09 09:57:00       0.83
# 401243   C581499         M        -1 2011-12-09 10:28:00     224.69
# 401410   C581568     21258        -5 2011-12-09 11:57:00      10.95
# 401411   C581569     84978        -1 2011-12-09 11:58:00       1.25
# 401412   C581569     20979        -5 2011-12-09 11:58:00       1.25
#
#        CustomerID         Country  weekday  month  hour
# 141       14527.0  United Kingdom        2     12     9
# 154       15311.0  United Kingdom        2     12     9
# 235       17548.0  United Kingdom        2     12    10
# 236       17548.0  United Kingdom        2     12    10
# 237       17548.0  United Kingdom        2     12    10
# ...           ...             ...      ...    ...   ...
# 401159    14397.0  United Kingdom        4     12     9
# 401243    15498.0  United Kingdom        4     12    10
# 401410    15311.0  United Kingdom        4     12    11
# 401411    17315.0  United Kingdom        4     12    11
# 401412    17315.0  United Kingdom        4     12    11
#
# [8872 rows x 10 columns]

# %%
# 환불하지 않은 데이터만 활용
df = df[df.Quantity > 0]

# %%
df[list_numerical_columns].describe()
# Out:
#             Quantity      UnitPrice
# count  392732.000000  392732.000000
# mean       13.153718       3.125596
# std       181.588420      22.240725
# min         1.000000       0.000000
# 25%         2.000000       1.250000
# 50%         6.000000       1.950000
# 75%        12.000000       3.750000
# max     80995.000000    8142.750000

# %%
sns.boxplot(df["Quantity"])

# 너무 큰 이상치는 제거(10000개 이상을 이상치로 정의)
# Out:
# <Axes: ylabel='Quantity'>

# %%
# 10000개 미만 이해 구매 건 확인
df = df[df.Quantity < 10000]

# %%
sns.boxplot(df["Quantity"])
# Out:
# <Axes: ylabel='Quantity'>

# %%
sns.boxplot(df["UnitPrice"])
# Out:
# <Axes: ylabel='UnitPrice'>

# %% [markdown]
# ---
# 인사이트
# 1. 일부 너무 큰 Quantity는 이상치로 제외

# %% [markdown]
# ## 22. Data Processing 2

# %% [markdown]
# ### 22.1. Missing Values

# %%
df.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# weekday        0
# month          0
# hour           0
# dtype: int64

# %% [markdown]
# ### 22.2. Feature Engineering
# - RFM을 구하기 위한 Feature 생성
# - Recency Feature
# - Frequency Feature
# - Monetary Feature

# %%
df.head()
# Out:
#   InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice CustomerID  \
# 0    536365    85123A         6 2010-12-01 08:26:00       2.55    17850.0
# 1    536365     71053         6 2010-12-01 08:26:00       3.39    17850.0
# 2    536365    84406B         8 2010-12-01 08:26:00       2.75    17850.0
# 3    536365    84029G         6 2010-12-01 08:26:00       3.39    17850.0
# 4    536365    84029E         6 2010-12-01 08:26:00       3.39    17850.0
#
#           Country  weekday  month  hour
# 0  United Kingdom        2     12     8
# 1  United Kingdom        2     12     8
# 2  United Kingdom        2     12     8
# 3  United Kingdom        2     12     8
# 4  United Kingdom        2     12     8

# %%
# Recency Feature - 가장 최근 행동
df_customer_last_date = df.groupby("CustomerID").agg(max)["InvoiceDate"].reset_index()
df_customer_last_date.head()
# Out:
#    CustomerID         InvoiceDate
# 0     12347.0 2011-12-07 15:52:00
# 1     12348.0 2011-09-25 13:13:00
# 2     12349.0 2011-11-21 09:51:00
# 3     12350.0 2011-02-02 16:01:00
# 4     12352.0 2011-11-03 14:37:00

# %%
# 가장 최근 날짜로부터 recency 확인
df_customer_last_date["recency"] = (df_customer_last_date["InvoiceDate"] - df["InvoiceDate"].max()).dt.days

# %%
df_recency = df_customer_last_date.drop(columns = ["InvoiceDate"])
df_recency.head()
# Out:
#    CustomerID  recency
# 0     12347.0       -2
# 1     12348.0      -75
# 2     12349.0      -19
# 3     12350.0     -310
# 4     12352.0      -36

# %%
# Frequency Feature - 빈도 높은 행동
df_frequency = df[["CustomerID", "InvoiceNo"]].drop_duplicates().groupby("CustomerID").count().reset_index()
df_frequency.rename(columns = {"InvoiceNo" : "frequency"}, inplace = True)
df_frequency.head()
# Out:
#    CustomerID  frequency
# 0     12347.0          7
# 1     12348.0          4
# 2     12349.0          1
# 3     12350.0          1
# 4     12352.0          8

# %%
# Monetary Feature - 구매 관련 행동
df["monetary_row"] = df["Quantity"] * df["UnitPrice"]
df_monetary = df.groupby("CustomerID").agg(sum)["monetary_row"].reset_index()
df_monetary.rename(columns = {'monetary_row' : 'monetary'}, inplace = True)
df_monetary.head()
# Out:
# <ipython-input-57-d51ee0951ccc>:3: FutureWarning: The operation <built-in function sum> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   df_monetary = df.groupby("CustomerID").agg(sum)["monetary_row"].reset_index()
#    CustomerID  monetary
# 0     12347.0   4310.00
# 1     12348.0   1797.24
# 2     12349.0   1757.55
# 3     12350.0    334.40
# 4     12352.0   2506.04

# %%
# 테이블 합치기
df_rfm = df_recency.merge(df_frequency, on="CustomerID").merge(df_monetary, on="CustomerID")

# %%
df_rfm
# Out:
#       CustomerID  recency  frequency  monetary
# 0        12347.0       -2          7   4310.00
# 1        12348.0      -75          4   1797.24
# 2        12349.0      -19          1   1757.55
# 3        12350.0     -310          1    334.40
# 4        12352.0      -36          8   2506.04
# ...          ...      ...        ...       ...
# 4332     18280.0     -278          1    180.60
# 4333     18281.0     -181          1     80.82
# 4334     18282.0       -8          2    178.05
# 4335     18283.0       -4         16   2045.53
# 4336     18287.0      -43          3   1837.28
#
# [4337 rows x 4 columns]

# %%
df_rfm["frequency"]
# Out:
# 0        7
# 1        4
# 2        1
# 3        1
# 4        8
#         ..
# 4332     1
# 4333     1
# 4334     2
# 4335    16
# 4336     3
# Name: frequency, Length: 4337, dtype: int64

# %%
# RFM score
df_rfm["recency_ntile"] = pd.qcut(df_rfm["recency"], 5, labels = [1, 2, 3, 4, 5])
df_rfm["frequency_ntile"] = pd.qcut(df_rfm["frequency"].rank(method = 'first'), 5, labels = [1, 2, 3, 4, 5])
df_rfm["monetary_ntile"] = pd.qcut(df_rfm["monetary"], 5, labels = [1, 2, 3, 4, 5])

# %%
df_rfm.head()
# Out:
#    CustomerID  recency  frequency  monetary recency_ntile frequency_ntile  \
# 0     12347.0       -2          7   4310.00             5               5
# 1     12348.0      -75          4   1797.24             2               4
# 2     12349.0      -19          1   1757.55             4               1
# 3     12350.0     -310          1    334.40             1               1
# 4     12352.0      -36          8   2506.04             3               5
#
#   monetary_ntile
# 0              5
# 1              4
# 2              4
# 3              2
# 4              5

# %% [markdown]
# ### 22.3. Feature Transformation
# - Feature Scaling
# - Standardization과 MinMaxScaling은 다름
# - MinMaxScaling은 [0, 1]로 값을 scaling하는 것 (e.g. sklearn의 MinMaxScaler())
# - Standardization은 정규분포의 표준화를 활용하여 Scaling하는 것 (e.g. sklearn의 StandardScaler())

# %%
# kmeans clustering을 위한 feature
df_rfm_clustering = df_rfm.copy()

# %%
df_rfm_clustering = df_rfm_clustering[["CustomerID", "recency", "frequency", "monetary"]]
df_rfm_clustering.head()
# Out:
#    CustomerID  recency  frequency  monetary
# 0     12347.0       -2          7   4310.00
# 1     12348.0      -75          4   1797.24
# 2     12349.0      -19          1   1757.55
# 3     12350.0     -310          1    334.40
# 4     12352.0      -36          8   2506.04

# %%
scaler = MinMaxScaler()
list_scaling = ["recency", "frequency", "monetary"]
df_rfm_clustering.loc[:, list_scaling] = scaler.fit_transform(df_rfm_clustering[list_scaling])
df_rfm_clustering.head()
# Out:
#    CustomerID   recency  frequency  monetary
# 0     12347.0  0.994652   0.028708  0.015371
# 1     12348.0  0.799465   0.014354  0.006404
# 2     12349.0  0.949198   0.000000  0.006262
# 3     12350.0  0.171123   0.000000  0.001183
# 4     12352.0  0.903743   0.033493  0.008933

# %% [markdown]
# ---
# ### 22.4. 요약
# 최종 생성 Feature의 특성
# - df_rfm: rfm heuristic 분석을 위한 Feature
# - df_rfm_clustering: rfm clustering 분석을 위한 Feature

# %% [markdown]
# ## 4. Model Analysis

# %% [markdown]
# ### 4.1. Heuristic RFM Analysis

# %%
df_heuristic_rfm = df_rfm.groupby(["recency_ntile", "monetary_ntile", "frequency_ntile"]).agg(np.mean).reset_index()
df_heuristic_rfm
# Out:
#     recency_ntile monetary_ntile frequency_ntile    CustomerID     recency  \
# 0               1              1               1  14129.610811 -285.291892
# 1               1              1               2  17022.155844 -273.428571
# 2               1              1               3  16353.809524 -237.238095
# 3               1              1               4  16922.666667 -211.666667
# 4               1              1               5           NaN         NaN
# ..            ...            ...             ...           ...         ...
# 120             5              5               1  15195.000000   -3.000000
# 121             5              5               2  13868.000000   -7.000000
# 122             5              5               3  13943.800000   -8.600000
# 123             5              5               4  14383.317073   -7.024390
# 124             5              5               5  15288.861671   -5.446686
#
#      frequency      monetary
# 0     1.000000    144.089135
# 1     1.032468    147.116688
# 2     2.000000    161.810000
# 3     3.000000    208.880000
# 4          NaN           NaN
# ..         ...           ...
# 120   1.000000   3861.000000
# 121   2.000000   3192.540000
# 122   2.800000   3508.084000
# 123   4.390244   3293.502927
# 124  18.253602  11229.657464
#
# [125 rows x 7 columns]

# %%
# VIP 고객에게 마케팅 진행
# recency_ntitle == 5, frequency_ntile == 5, monetary_ntile == 5
df_rfm[(df_rfm.recency_ntile == 5) & (df_rfm.monetary_ntile == 5) & (df_rfm.frequency_ntile == 5)]
# Out:
#       CustomerID  recency  frequency  monetary recency_ntile frequency_ntile  \
# 0        12347.0       -2          7   4310.00             5               5
# 14       12362.0       -3         10   5226.23             5               5
# 55       12417.0       -3          9   3649.10             5               5
# 70       12433.0       -1          7  13375.87             5               5
# 74       12437.0       -2         18   4951.41             5               5
# ...          ...      ...        ...       ...           ...             ...
# 4296     18229.0      -12         20   7276.90             5               5
# 4297     18230.0       -9          7   2810.20             5               5
# 4306     18241.0      -10         17   2073.09             5               5
# 4308     18245.0       -7          7   2567.06             5               5
# 4326     18272.0       -3          6   3078.58             5               5
#
#      monetary_ntile
# 0                 5
# 14                5
# 55                5
# 70                5
# 74                5
# ...             ...
# 4296              5
# 4297              5
# 4306              5
# 4308              5
# 4326              5
#
# [347 rows x 7 columns]

# %%
# 이전에 구매를 많이 했지만, 최근에 구매가 적은 고객
# recency_ntitle == 1, frequency_ntile == 5, monetary_ntile == 5

df_rfm[(df_rfm.recency_ntile == 1) & (df_rfm.monetary_ntile == 5) & (df_rfm.frequency_ntile == 5)]
# Out:
#       CustomerID  recency  frequency  monetary recency_ntile frequency_ntile  \
# 565      13093.0     -276          8   7832.47             1               5
# 2117     15235.0     -218         12   2247.51             1               5
# 3569     17230.0     -264          8   3638.41             1               5
# 3763     17504.0     -206          9   2997.03             1               5
# 4015     17850.0     -372         34   5391.21             1               5
#
#      monetary_ntile
# 565               5
# 2117              5
# 3569              5
# 3763              5
# 4015              5

# %%
# 구매와 매출이 높지만, 1-2달 동안 구매가 없음, 쿠폰 지급 가능
# recency_ntitle == 3, monetary_ntile == 5, frequency_ntile == 5

df_rfm[(df_rfm.recency_ntile == 3) & (df_rfm.monetary_ntile == 5) & (df_rfm.frequency_ntile == 5)]
# Out:
#       CustomerID  recency  frequency  monetary recency_ntile frequency_ntile  \
# 4        12352.0      -36          8   2506.04             3               5
# 68       12431.0      -36         15   6419.95             3               5
# 91       12457.0      -66          7   2363.23             3               5
# 199      12594.0      -38         10   3338.22             3               5
# 234      12637.0      -67          8   6002.90             3               5
# ...          ...      ...        ...       ...           ...             ...
# 4086     17940.0      -49         10   4020.04             3               5
# 4104     17965.0      -38         14   2599.19             3               5
# 4134     18008.0      -70          9   2116.19             3               5
# 4293     18226.0      -44         11   5228.05             3               5
# 4316     18257.0      -39          8   2337.63             3               5
#
#      monetary_ntile
# 4                 5
# 68                5
# 91                5
# 199               5
# 234               5
# ...             ...
# 4086              5
# 4104              5
# 4134              5
# 4293              5
# 4316              5
#
# [85 rows x 7 columns]

# %% [markdown]
# ### 4.2. K-Means RFM Analysis

# %%
df_rfm_clustering
# Out:
#       CustomerID   recency  frequency  monetary
# 0        12347.0  0.994652   0.028708  0.015371
# 1        12348.0  0.799465   0.014354  0.006404
# 2        12349.0  0.949198   0.000000  0.006262
# 3        12350.0  0.171123   0.000000  0.001183
# 4        12352.0  0.903743   0.033493  0.008933
# ...          ...       ...        ...       ...
# 4332     18280.0  0.256684   0.000000  0.000634
# 4333     18281.0  0.516043   0.000000  0.000278
# 4334     18282.0  0.978610   0.004785  0.000625
# 4335     18283.0  0.989305   0.071770  0.007290
# 4336     18287.0  0.885027   0.009569  0.006547
#
# [4337 rows x 4 columns]

# %%
sum_of_squared_distances = []
K = range(2, 20)
for k in K:
    km = KMeans(n_clusters = k)
    km = km.fit(df_rfm_clustering.drop("CustomerID", axis = 1))
    sum_of_squared_distances.append(km.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# 적당한 클러스터 수 설정
plt.plot(K, sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# Elbow Method는 클러스터 개수(K)를 변화시켜가면서 K-means 알고리즘을 수행한 결과를 나타낸 그래프.
# 그래프에서 팔꿈치 모양을 띄는 지점이 최적의 클러스터 개수.
#
# 이 방법은 클러스터 개수를 증가시켜가며 알고리즘을 실행하고, 클러스터마다 제곱오차합(SSE, Sum of Squared Errors)을 구한 뒤, 이를 차트로 표시함.
#
# 팔꿈치는 k = 5

# %%
# 클러스터 수 설정
km_final = KMeans(n_clusters = 5)
km_final = km_final.fit(df_rfm_clustering.drop("CustomerID", axis = 1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df_rfm_clustering["cluster_number"] = km_final.predict(df_rfm_clustering.drop("CustomerID", axis = 1))

# %%
df_rfm_clustering
# Out:
#       CustomerID   recency  frequency  monetary  cluster_number
# 0        12347.0  0.994652   0.028708  0.015371               0
# 1        12348.0  0.799465   0.014354  0.006404               4
# 2        12349.0  0.949198   0.000000  0.006262               0
# 3        12350.0  0.171123   0.000000  0.001183               3
# 4        12352.0  0.903743   0.033493  0.008933               0
# ...          ...       ...        ...       ...             ...
# 4332     18280.0  0.256684   0.000000  0.000634               1
# 4333     18281.0  0.516043   0.000000  0.000278               2
# 4334     18282.0  0.978610   0.004785  0.000625               0
# 4335     18283.0  0.989305   0.071770  0.007290               0
# 4336     18287.0  0.885027   0.009569  0.006547               0
#
# [4337 rows x 5 columns]

# %%
# cluste별 RFM score 패턴 확인
cluster_result = df_rfm_clustering.drop(columns = ["CustomerID"]).groupby("cluster_number").agg(np.mean)

# %%
cluster_result
# Out:
#                  recency  frequency  monetary
# cluster_number
# 0               0.951677   0.026974  0.011817
# 1               0.338438   0.002159  0.002100
# 2               0.575833   0.005420  0.002689
# 3               0.101245   0.001716  0.001368
# 4               0.806749   0.008158  0.003755

# %% [markdown]
# ---
# 결론
# - 클러스터링 분석보다는 휴리스틱 분석이 더 효과적으로 활용될 수 있을 것으로 보임
# - 클러스터링 최적화 필요

# %%
# 클러스터 데이터 추출
df_rfm_clustering.to_csv("cluster.csv")
